# %%
import pandas as pd

# %%
df = pd.read_excel("main_data.xlsx")

# %%
df.head()
# Out:
#    record_id     region country commodity_value            edu_level  \
# 0    1234175  Bono East   Ghana             Yam      Basic Education
# 1    1234300  Bono East   Ghana             Yam                  NaN
# 2    1234301  Bono East   Ghana      Maize, Yam                  NaN
# 3    1235047  Bono East   Ghana      Maize, Yam      Basic Education
# 4    1235048  Bono East   Ghana      Maize, Yam  Secondary Education
#
#   fbo_membership social_membership smb_clim_infor climate_access  \
# 0            Yes               Yes            Yes            Yes
# 1            Yes               Yes             No            Yes
# 2             No               Yes             No            Yes
# 3            Yes               Yes            Yes            Yes
# 4            Yes               Yes            Yes            Yes
#
#   clim_infor_useful  ...       ED  Number_Qty UnitpriceGHC  \
# 0       Very useful  ...      NaN         NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Columns: 135 entries, record_id to EM
# dtypes: float64(51), int64(1), object(83)
# memory usage: 580.2+ KB

# %% [markdown]
# ### find and drop duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 550

# %% [markdown]
# ### find columns with missing data

# %%
df.isna().sum()
# Out:
# record_id           0
# region              0
# country             0
# commodity_value     7
# edu_level          18
#                    ..
# EI                 21
# NumberQty          25
# EK                 27
# EL                 21
# EM                 21
# Length: 135, dtype: int64

# %%
#filling null values with N/A
#df.fillna("N/A", inplace = True)

# %%
df.head()
# Out:
#    record_id     region country commodity_value            edu_level  \
# 0    1234175  Bono East   Ghana             Yam      Basic Education
# 1    1234300  Bono East   Ghana             Yam                  NaN
# 2    1234301  Bono East   Ghana      Maize, Yam                  NaN
# 3    1235047  Bono East   Ghana      Maize, Yam      Basic Education
# 4    1235048  Bono East   Ghana      Maize, Yam  Secondary Education
#
#   fbo_membership social_membership smb_clim_infor climate_access  \
# 0            Yes               Yes            Yes            Yes
# 1            Yes               Yes             No            Yes
# 2             No               Yes             No            Yes
# 3            Yes               Yes            Yes            Yes
# 4            Yes               Yes            Yes            Yes
#
#   clim_infor_useful  ...       ED  Number_Qty UnitpriceGHC  \
# 0       Very useful  ...      NaN         NaN          NaN
# ...

# %% [markdown]
# ### Trim excess whitespaces

# %%
#def trimSpaces(df):
#    trimString = lambda x: x.strip() if isinstance(x, str) else x
#    return df.applymap(trimString)

# %%
#df = trimSpaces(df)

# %%
df = pd.DataFrame(df)
# Use applymap() and strip() to remove whitespace
trimdf = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
trimdf
# Out:
#      record_id      region country commodity_value            edu_level  \
# 0      1234175   Bono East   Ghana             Yam      Basic Education
# 1      1234300   Bono East   Ghana             Yam                  NaN
# 2      1234301   Bono East   Ghana      Maize, Yam                  NaN
# 3      1235047   Bono East   Ghana      Maize, Yam      Basic Education
# 4      1235048   Bono East   Ghana      Maize, Yam  Secondary Education
# ..         ...         ...     ...             ...                  ...
# 545    1313991  Upper West   Ghana           Maize  No Formal Education
# 546    1313992  Upper West   Ghana           Maize  No Formal Education
# 547    1314044  Upper West   Ghana           Maize  No Formal Education
# 548    1314045  Upper West   Ghana           Maize  No Formal Education
# 549    1314053  Upper West   Ghana           Maize  No Formal Education
#
#     fbo_membership social_membership smb_clim_infor climate_access  \
# ...

# %% [markdown]
# ### split 'AutoRecordedGIS' column to 'longitude' and 'latitude'

# %%
trimdf[['latitude', 'longitude', 'altitude']] = df['AutoRecordedGIS'].str.split(',', expand=True)

# %%
trimdf[['AutoRecordedGIS','latitude', 'longitude', 'altitude']]
# Out:
#                 AutoRecordedGIS   latitude   longitude altitude
# 0      7.9743758,-1.8167344,8.5  7.9743758  -1.8167344      8.5
# 1    7.9736358,-1.8547442,4.288  7.9736358  -1.8547442    4.288
# 2    7.9737166,-1.8547034,8.576  7.9737166  -1.8547034    8.576
# 3     7.9468923,-1.6227417,12.0  7.9468923  -1.6227417     12.0
# 4     7.9475395,-1.6235471,5.36  7.9475395  -1.6235471     5.36
# ..                          ...        ...         ...      ...
# 545                         NaN        NaN         NaN      NaN
# 546                         NaN        NaN         NaN      NaN
# 547                         NaN        NaN         NaN      NaN
# 548                         NaN        NaN         NaN      NaN
# 549                         NaN        NaN         NaN      NaN
#
# [550 rows x 4 columns]

# %% [markdown]
# ### export cleaned data

# %%
trimdf.to_csv('md.csv', index=False)
